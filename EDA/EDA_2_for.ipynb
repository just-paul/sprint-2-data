# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
master_df = pd.read_csv('master_df.csv').drop(columns = 'Unnamed: 0')
master_df.head()
# Out:
#          date  position                track_id            track_name  \
# 0  2017-01-01         1  0kN8xEmgMW9mh7UmDYHlJP  Versace on the Floor
# 1  2017-01-01         2  5uCax9HTNlzGybIStD3vDh  Say You Won't Let Go
# 2  2017-01-01         3  7BKLCZ1jbUBVqRi2FVlTVw                Closer
# 3  2017-01-01         4  2rizacJSyD9S1IQUxUxnsK           All We Know
# 4  2017-01-01         5  5MFzQMkrl1FOOng9tq6R9r      Don't Wanna Know
#
#              artist  streams               artist_id       artist_name  \
# 0        Bruno Mars   185236  0du5cEVh5yTK9QJze8zA0C        Bruno Mars
# 1      James Arthur   180552  4IWBUUAFIplrNtaOHcJPRM      James Arthur
# 2  The Chainsmokers   158720  69GGBxA162lTqCwzJG5jLp  The Chainsmokers
# 3  The Chainsmokers   130874  69GGBxA162lTqCwzJG5jLp  The Chainsmokers
# 4          Maroon 5   129656  04gDigrS5kc9YWfZHwBETP          Maroon 5
#
#                  album_id  duration  ... liveness  valence    tempo  \
# ...

# %%
master_df.columns
# Out:
# Index(['date', 'position', 'track_id', 'track_name', 'artist', 'streams',
#        'artist_id', 'artist_name', 'album_id', 'duration', 'release_date',
#        'popularity', 'danceability', 'energy', 'key', 'loudness', 'mode',
#        'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'total_followers', 'genres', 'year', 'month', 'day',
#        'day_of_week', 'category'],
#       dtype='object')

# %%
#####
# foreign artist
audio_feat = ['duration','popularity', 'danceability', 'energy', 'key', 'loudness', 'mode','speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo']

# %% [markdown]
# # Audio Features

# %% [markdown]
# # Foreign artist 2017

# %%
df_for_17 = master_df[(master_df['year'] == 2017) & (master_df['category'] == 'foreign')]
df_for_17.head()
# Out:
#          date  position                track_id            track_name  \
# 0  2017-01-01         1  0kN8xEmgMW9mh7UmDYHlJP  Versace on the Floor
# 1  2017-01-01         2  5uCax9HTNlzGybIStD3vDh  Say You Won't Let Go
# 2  2017-01-01         3  7BKLCZ1jbUBVqRi2FVlTVw                Closer
# 3  2017-01-01         4  2rizacJSyD9S1IQUxUxnsK           All We Know
# 4  2017-01-01         5  5MFzQMkrl1FOOng9tq6R9r      Don't Wanna Know
#
#              artist  streams               artist_id       artist_name  \
# 0        Bruno Mars   185236  0du5cEVh5yTK9QJze8zA0C        Bruno Mars
# 1      James Arthur   180552  4IWBUUAFIplrNtaOHcJPRM      James Arthur
# 2  The Chainsmokers   158720  69GGBxA162lTqCwzJG5jLp  The Chainsmokers
# 3  The Chainsmokers   130874  69GGBxA162lTqCwzJG5jLp  The Chainsmokers
# 4          Maroon 5   129656  04gDigrS5kc9YWfZHwBETP          Maroon 5
#
#                  album_id  duration  ... liveness  valence    tempo  \
# ...

# %%
for_list17 = df_for_17.groupby(['track_id'])[['streams']].sum().sort_values(by ='streams', ascending = False)[:100]
for_list17 = for_list17.index
for_list17
# Out:
# Index(['7qiZfU4dY1lWllzX7mPBI3', '5uCax9HTNlzGybIStD3vDh',
#        '0kN8xEmgMW9mh7UmDYHlJP', '0KKkJNfGyhkQ5aFogxQAPU',
#        '6RUKPb4LETWmmr3iAEQktW', '5CtI0qwDJkDQGwXD1H1cLb',
#        '0tgVpDi06FyKpA1z0VMD4v', '3NdDpSvN911VPGivFlV5d0',
#        '1x5sYLZiu9r5E43kMlt9f8', '3DXncPQOG4VBw3QHh3S817',
#        '7BKLCZ1jbUBVqRi2FVlTVw', '5Z3GHaZ6ec9bsiI5BenrbY',
#        '1wjzFQodRWrPcQ0AnYnvQ9', '6EpRaXYhGOB3fj4V2uDkMJ',
#        '4iLqG9SeJSnt0cSPICSjxv', '4nMlau89VAjmV7agkl7OY3',
#        '0dA2Mk56wEzDgegdC6R17g', '72jbDTw1piOOj770jWNeaG',
#        '74ODGXs4byLTRdnKGM4s6E', '0NiXXAI876aGImAd6rTj8w',
#        '1qOLh0tI7trd1zdDKxYZTe', '0ofbQMrRDsUaVKq2mGLEAb',
#        '2ekn2ttSfGqwhhate0LSR0', '6cAKeFFYW2aClZSUyvqAEW',
#        '1NDxZ7cFAo481dtYWdrUnR', '5hYTyyh2odQKphUbMqc5gN',
#        '6jA8HL9i4QGzsj6fjoxp8Y', '1louJpMmzEicAn7lzDalPW',
#        '79cuOz3SPQTuFrp8WgftAu', '0tKcYR2II1VCQWT79i5NrW',
#        '6b8Be6ljOzmkOmFslEb23P', '5Ua3GXyHwiSfpNTMjq6m2z',
# ...

# %%
audio_feat_for_df17 = df_for_17[df_for_17['track_id'].isin(for_list17)]
audio_feat_for_df17 = audio_feat_for_df17[audio_feat].drop_duplicates()
audio_feat_for_df17
# Out:
#        duration  popularity  danceability  energy  key  loudness  mode  \
# 0        261240          73         0.578   0.574    2    -6.209     1
# 1        211466          85         0.358   0.557   10    -7.398     1
# 2        244960          84         0.748   0.524    8    -5.599     1
# 3        194080          68         0.662   0.586    0    -8.821     1
# 4        214480           1         0.783   0.623    7    -6.126     1
# ...         ...         ...           ...     ...  ...       ...   ...
# 38879    239000          81         0.258   0.437   11    -6.593     0
# 38923    174800           1         0.659   0.717    8    -4.202     1
# 43064    198237           2         0.849   0.581    1    -5.243     0
# 47283    201000          80         0.681   0.372    5    -8.237     1
# 47749    199849           2         0.795   0.615    5    -5.211     0
#
#        speechiness  acousticness  instrumentalness  liveness  valence    tempo
# ...

# %%
audio_feat_for_df17['duration'] = audio_feat_for_df17['duration'] / 60000
audio_feat_for_df17
# Out:
#        duration  popularity  danceability  energy  key  loudness  mode  \
# 0      4.354000          73         0.578   0.574    2    -6.209     1
# 1      3.524433          85         0.358   0.557   10    -7.398     1
# 2      4.082667          84         0.748   0.524    8    -5.599     1
# 3      3.234667          68         0.662   0.586    0    -8.821     1
# 4      3.574667           1         0.783   0.623    7    -6.126     1
# ...         ...         ...           ...     ...  ...       ...   ...
# 38879  3.983333          81         0.258   0.437   11    -6.593     0
# 38923  2.913333           1         0.659   0.717    8    -4.202     1
# 43064  3.303950           2         0.849   0.581    1    -5.243     0
# 47283  3.350000          80         0.681   0.372    5    -8.237     1
# 47749  3.330817           2         0.795   0.615    5    -5.211     0
#
#        speechiness  acousticness  instrumentalness  liveness  valence    tempo
# ...

# %%
audio_feat_for_df17.describe()
# Out:
#          duration  popularity  danceability      energy         key  \
# count  100.000000  100.000000    100.000000  100.000000  100.000000
# mean     3.593745   41.150000      0.652750    0.627250    5.210000
# std      0.453662   35.578729      0.133447    0.140019    3.502654
# min      2.847100    0.000000      0.258000    0.253000    0.000000
# 25%      3.295062    1.000000      0.595250    0.531500    2.000000
# 50%      3.523575   56.500000      0.659500    0.629500    5.000000
# 75%      3.816212   75.250000      0.741250    0.739250    8.000000
# max      5.160000   86.000000      0.909000    0.932000   11.000000
#
#          loudness        mode  speechiness  acousticness  instrumentalness  \
# count  100.000000  100.000000   100.000000    100.000000        100.000000
# mean    -5.802520    0.710000     0.083709      0.213608          0.003500
# std      1.765098    0.456048     0.075417      0.199302          0.024684
# ...

# %% [markdown]
# # Foreign artist 2018

# %%
df_for_18 = master_df[(master_df['year'] == 2018) & (master_df['category'] == 'foreign')]
df_for_18.head(5)
# Out:
#              date  position                track_id  \
# 56219  2018-01-01         1  0ofbQMrRDsUaVKq2mGLEAb
# 56220  2018-01-01         2  0tgVpDi06FyKpA1z0VMD4v
# 56221  2018-01-01         3  3hBBKuWJfxlIlnd9QFoC8k
# 56222  2018-01-01         4  1mXVgsBdtIVeCLJnSnmtdV
# 56223  2018-01-01         5  2ekn2ttSfGqwhhate0LSR0
#
#                        track_name          artist  streams  \
# 56219                      Havana  Camila Cabello   155633
# 56220                     Perfect      Ed Sheeran   134756
# 56221  What Lovers Do (feat. SZA)        Maroon 5   130898
# 56222        Too Good At Goodbyes       Sam Smith   130798
# 56223                   New Rules        Dua Lipa   125472
#
#                     artist_id     artist_name                album_id  \
# 56219  4nDoRrQiYLoBzwC5BhVJzF  Camila Cabello  5chBPOVY2I0bG5V3igb5QL
# 56220  6eUKZXaKkcviH0Ku9w2n3V      Ed Sheeran  3T4tUhGYeRNVUGevb0wThu
# 56221  04gDigrS5kc9YWfZHwBETP        Maroon 5  1Jmq5HEJeA9kNi2SgQul4U
# ...

# %%
for_list18 = df_for_18.groupby(['track_id'])[['streams']].sum().sort_values(by ='streams', ascending = False)[:100]
for_list18 = for_list18.index
for_list18
# Out:
# Index(['76cy1WJvNGJTj78UqeA5zr', '7fa9MBXhVfQ8P8Df9OEbD8',
#        '630sXRhIcfwr2e4RdNtjKN', '10Igtw8bSDyyFs7KIsKngZ',
#        '1mXVgsBdtIVeCLJnSnmtdV', '0tgVpDi06FyKpA1z0VMD4v',
#        '1rfofaqEpACxVEHIZBJe6W', '5uCax9HTNlzGybIStD3vDh',
#        '5CLGzJsGqhCEECcpnFQA8x', '3BPoSr2pO34Aan6alFfVto',
#        '4eWQlBRaTjPPUlzacqEeoQ', '0Eqg0CQ7bK3RQIMPw1A7pl',
#        '2G7V7zsVDxg1yRsu7Ew9RJ', '2ARqIya5NAuvFVHSN3bL0m',
#        '4VUwkH455At9kENOfzTqmF', '2dpaYNEQHiRxtZbfNsse99',
#        '2BgEsaKNfHUdlh97KmvFyo', '08bNPGLD8AhKpnnERrAc6G',
#        '5Z3GHaZ6ec9bsiI5BenrbY', '2ekn2ttSfGqwhhate0LSR0',
#        '74ODGXs4byLTRdnKGM4s6E', '3Vo4wInECJQuz9BIBMOu8i',
#        '7Fg342AJtNsIDdwCfX0paC', '09IStsImFySgyp0pIQdqAc',
#        '2rPE9A1vEgShuZxxzR2tZH', '2RttW7RAu5nOAfq6YFvApB',
#        '7uzmGiiJyRfuViKKK3lVmR', '0d2iYfpKoM0QCKvcLCkBao',
#        '7iDa6hUg2VgEL1o1HjmfBn', '7ef4DlsgrMEH11cDZd32M6',
#        '3hBBKuWJfxlIlnd9QFoC8k', '3towKHKVOXCCcL1fHv6xFO',
# ...

# %%
audio_feat_for_df18 = df_for_18[df_for_18['track_id'].isin(for_list18)]
audio_feat_for_df18 = audio_feat_for_df18[audio_feat].drop_duplicates()
audio_feat_for_df18
# Out:
#        duration  popularity  danceability  energy  key  loudness  mode  \
# 56220    263400          86         0.599   0.448    8    -6.312     1
# 56221    199849           2         0.795   0.615    5    -5.211     0
# 56222    201000          80         0.681   0.372    5    -8.237     1
# 56223    209320          79         0.762   0.700    9    -6.021     0
# 56224    202546          80         0.798   0.539    1    -6.351     1
# ...         ...         ...           ...     ...  ...       ...   ...
# 93956    201197          63         0.702   0.623    0    -8.360     1
# 93958    212002          64         0.697   0.551    5    -6.179     0
# 95778    190560          53         0.675   0.729    8    -4.383     1
# 96848    205440          64         0.538   0.409    9    -6.581     0
# 97918    207333           7         0.724   0.647    1    -5.642     1
#
#        speechiness  acousticness  instrumentalness  liveness  valence    tempo
# ...

# %%
audio_feat_for_df18['duration'] = audio_feat_for_df18['duration'] / 60000
audio_feat_for_df18
# Out:
#        duration  popularity  danceability  energy  key  loudness  mode  \
# 56220  4.390000          86         0.599   0.448    8    -6.312     1
# 56221  3.330817           2         0.795   0.615    5    -5.211     0
# 56222  3.350000          80         0.681   0.372    5    -8.237     1
# 56223  3.488667          79         0.762   0.700    9    -6.021     0
# 56224  3.375767          80         0.798   0.539    1    -6.351     1
# ...         ...         ...           ...     ...  ...       ...   ...
# 93956  3.353283          63         0.702   0.623    0    -8.360     1
# 93958  3.533367          64         0.697   0.551    5    -6.179     0
# 95778  3.176000          53         0.675   0.729    8    -4.383     1
# 96848  3.424000          64         0.538   0.409    9    -6.581     0
# 97918  3.455550           7         0.724   0.647    1    -5.642     1
#
#        speechiness  acousticness  instrumentalness  liveness  valence    tempo
# ...

# %%
audio_feat_for_df18.describe()
# Out:
#          duration  popularity  danceability      energy         key  \
# count  100.000000  100.000000    100.000000  100.000000  100.000000
# mean     3.588288   57.980000      0.648200    0.613060    5.750000
# std      0.491174   31.151951      0.127604    0.148846    3.699236
# min      2.184400    0.000000      0.265000    0.235000    0.000000
# 25%      3.327113   53.750000      0.593750    0.517000    2.000000
# 50%      3.488958   74.000000      0.677500    0.623000    7.000000
# 75%      3.793050   79.000000      0.739250    0.716250    9.000000
# max      5.160000   86.000000      0.853000    0.940000   11.000000
#
#          loudness        mode  speechiness  acousticness  instrumentalness  \
# count  100.000000  100.000000   100.000000    100.000000        100.000000
# mean    -6.065470    0.700000     0.082817      0.261514          0.001492
# std      1.937804    0.460566     0.083969      0.238604          0.013211
# ...

# %% [markdown]
# # Foreign artist 2019

# %%
df_for_19 = master_df[(master_df['year'] == 2019) & (master_df['category'] == 'foreign')]
df_for_19.head(5)
# Out:
#               date  position                track_id  \
# 105866  2019-01-01         1  2rPE9A1vEgShuZxxzR2tZH
# 105867  2019-01-01         7  0Eqg0CQ7bK3RQIMPw1A7pl
# 105868  2019-01-01        10  3KkXRkHbMCARz0aVfEt68P
# 105869  2019-01-01        11  2dpaYNEQHiRxtZbfNsse99
# 105870  2019-01-01        12  4w8niZpiMy6qz1mntFA5uM
#
#                                             track_name         artist  \
# 105866                                   thank u, next  Ariana Grande
# 105867                                   Malibu Nights           LANY
# 105868   Sunflower - Spider-Man: Into the Spider-Verse    Post Malone
# 105869                                         Happier     Marshmello
# 105870  Taki Taki (with Selena Gomez, Ozuna & Cardi B)       DJ Snake
#
#         streams               artist_id    artist_name  \
# 105866   194707  66CXWjxzNUsdJxJ2JdwvnR  Ariana Grande
# 105867   135105  49tQo2QULno7gxHutgccqF           LANY
# ...

# %%
for_list19 = df_for_19.groupby(['track_id'])[['streams']].sum().sort_values(by ='streams', ascending = False)[:100]
for_list19 = for_list19.index
for_list19
# Out:
# Index(['18uwL0vNUanqZH0ro2QcOP', '3id2EVGKc3eFAMn9nFnB0r',
#        '3KkXRkHbMCARz0aVfEt68P', '0Eqg0CQ7bK3RQIMPw1A7pl',
#        '4OBZT9EnhYIV17t4pGw7ig', '2b8fOow8UzyDFAE27YhOZM',
#        '6v3KW9xbzN5yKLt9YKDYA2', '4ve2uzqdwnHr20G5YgMMqr',
#        '1pNAf6W7POwjOD8x8mWf8G', '70eFcWOvlMObDhURTqT4Fv',
#        '4pUCKHjJ4Ijewc37rRrvHn', '2BgEsaKNfHUdlh97KmvFyo',
#        '6Qs4SXO9dwPj5GKvVOv8Ki', '5p7ujcrUXASCNwRaWNHR1C',
#        '7COXchtUOMd6uIT6HvmRaI', '6TqXcAFInzjp0bODyvrWEq',
#        '0hVXuCcriWRGvwMV1r5Yn9', '2P91MQbaiQOfbiz9VqhqKQ',
#        '2dpaYNEQHiRxtZbfNsse99', '3e9HZxeyfWwjeyPAMmWSSQ',
#        '5KawlOMHjWeUjQtnuRs22c', '7fa9MBXhVfQ8P8Df9OEbD8',
#        '4VUwkH455At9kENOfzTqmF', '6b2RcmUt1g9N9mQ3CbjX2Y',
#        '1iWHabUgUuuKLBa0TzTHfk', '6ocbgoVGwYJhOv1GgI9NsF',
#        '3xaugmCyXrVkrDTXbFkMW3', '6vBdBCoOhKHiYDDOcorfNo',
#        '5uCax9HTNlzGybIStD3vDh', '7GbAp0HKPQW7WnFJAzMoRk',
#        '7qEHsqek33rTcFNT9PFqLf', '2wrJq5XKLnmhRXHIAf9xBa',
# ...

# %%
audio_feat_for_df19 = df_for_19[df_for_19['track_id'].isin(for_list19)]
audio_feat_for_df19 = audio_feat_for_df19[audio_feat].drop_duplicates()
audio_feat_for_df19
# Out:
#         duration  popularity  danceability  energy  key  loudness  mode  \
# 105867    286928          75         0.559   0.422   11   -11.890     1
# 105868    158040          84         0.760   0.479    2    -5.574     1
# 105869    214289          84         0.687   0.792    5    -2.749     1
# 105870    212500          78         0.842   0.801    8    -4.167     0
# 105871    205440          64         0.538   0.409    9    -6.581     0
# ...          ...         ...           ...     ...  ...       ...   ...
# 143022    358015          32         0.848   0.447    5   -10.560     0
# 143407    206458          16         0.505   0.340    4    -9.005     1
# 144527    183290          85         0.794   0.793   11    -4.521     0
# 146094    232853           4         0.746   0.450    7    -8.543     1
# 146245    163636          86         0.621   0.601    6    -5.616     0
#
#         speechiness  acousticness  instrumentalness  liveness  valence  \
# ...

# %%
audio_feat_for_df19['duration'] = audio_feat_for_df19['duration'] / 60000
audio_feat_for_df19
# Out:
#         duration  popularity  danceability  energy  key  loudness  mode  \
# 105867  4.782133          75         0.559   0.422   11   -11.890     1
# 105868  2.634000          84         0.760   0.479    2    -5.574     1
# 105869  3.571483          84         0.687   0.792    5    -2.749     1
# 105870  3.541667          78         0.842   0.801    8    -4.167     0
# 105871  3.424000          64         0.538   0.409    9    -6.581     0
# ...          ...         ...           ...     ...  ...       ...   ...
# 143022  5.966917          32         0.848   0.447    5   -10.560     0
# 143407  3.440967          16         0.505   0.340    4    -9.005     1
# 144527  3.054833          85         0.794   0.793   11    -4.521     0
# 146094  3.880883           4         0.746   0.450    7    -8.543     1
# 146245  2.727267          86         0.621   0.601    6    -5.616     0
#
#         speechiness  acousticness  instrumentalness  liveness  valence  \
# ...

# %%
audio_feat_for_df19.describe()
# Out:
#          duration  popularity  danceability      energy       key    loudness  \
# count  100.000000  100.000000    100.000000  100.000000  100.0000  100.000000
# mean     3.401513   65.230000      0.666390    0.582590    5.1500   -6.550350
# std      0.533788   25.706131      0.135122    0.159529    3.6108    2.305183
# min      2.181267    2.000000      0.288000    0.178000    0.0000  -16.541000
# 25%      3.052054   64.000000      0.598250    0.459250    2.0000   -7.708500
# 50%      3.357142   75.500000      0.693500    0.572500    5.0000   -6.337500
# 75%      3.602663   81.000000      0.756000    0.683750    8.0000   -5.004500
# max      5.966917   90.000000      0.901000    0.882000   11.0000   -2.150000
#
#              mode  speechiness  acousticness  instrumentalness    liveness  \
# count  100.000000   100.000000    100.000000        100.000000  100.000000
# mean     0.710000     0.085861      0.287035          0.004741    0.147803
# ...

# %% [markdown]
# # Foreign artist 2020

# %%
df_for_20 = master_df[(master_df['year'] == 2020) & (master_df['category'] == 'foreign')]
df_for_20.head(5)
# Out:
#               date  position                track_id  \
# 152149  2020-01-01         2  2b8fOow8UzyDFAE27YhOZM
# 152150  2020-01-01         3  696DnlkuDOXcMAnKlTgXXK
# 152151  2020-01-01         6  0BaMZMMEG7GWrUYsoGw8Yg
# 152152  2020-01-01         9  3GRSqlALWISqLeNncZMbpX
# 152153  2020-01-01        11  2wrJq5XKLnmhRXHIAf9xBa
#
#                                track_name          artist  streams  \
# 152149                           Memories        Maroon 5   222136
# 152150                            ROXANNE  Arizona Zervas   204600
# 152151                           Neneng B      Nik Makino   150208
# 152152                            Mean It            Lauv   141667
# 152153  10,000 Hours (with Justin Bieber)      Dan + Shay   135601
#
#                      artist_id     artist_name                album_id  \
# 152149  04gDigrS5kc9YWfZHwBETP        Maroon 5  3nR9B40hYLKLcR0Eph3Goc
# 152150  0vRvGUQVUjytro0xpb26bs  Arizona Zervas  6HJDrXs0hpebaRFKA1sF90
# ...

# %%
for_list20 = df_for_20.groupby(['track_id'])[['streams']].sum().sort_values(by ='streams', ascending = False)[:100]
for_list20 = for_list20.index
for_list20
# Out:
# Index(['4umIPjkehX1r7uhmGvXiSV', '7qEHsqek33rTcFNT9PFqLf',
#        '2b8fOow8UzyDFAE27YhOZM', '2wrJq5XKLnmhRXHIAf9xBa',
#        '4HBZA5flZLE435QTztThqH', '3R6Hl2e7hAyCfofRRToKAo',
#        '21jGcNKet2qwijlDFuPiPb', '7eJMfftS33KTjuF7lTsMCx',
#        '4nd9cEo5R4jGNcgPHDm7Ar', '1Cv1YLb4q0RzL6pybtaMLo',
#        '1rgnBhdG2JDFTbYkYRZAku', '3PfIrDoz19wz7qK7tYeu62',
#        '2gMXnyrvIjhVBUZwvLZDMP', '0t1kP63rueHleOhQkYSXFY',
#        '696DnlkuDOXcMAnKlTgXXK', '1x8pFCRfBnDqckyB6mlZci',
#        '4ja2gzrNh9VNigzoXfmbwD', '1xQ6trAsedVPCdbtDAmk0c',
#        '4nK5YrxbMGZstTLbvj6Gxw', '5iFwAOB2TFkPJk8sMlxP8g',
#        '6r7sdXUiKjgEx3I8GQRpSq', '4Ws314Ylb27BVsvlZOy30C',
#        '70eFcWOvlMObDhURTqT4Fv', '0Eqg0CQ7bK3RQIMPw1A7pl',
#        '3vAn0qZzdyuHamcrpkfiX3', '3CYH422oy1cZNoo0GTG1TK',
#        '5DqdesEfbRyOlSS3Tf6c29', '2P91MQbaiQOfbiz9VqhqKQ',
#        '4JUPEh2DVSXFGExu4Uxevz', '5uCax9HTNlzGybIStD3vDh',
#        '4a6q8CR2hzLk2plDkSxkfD', '5u1n1kITHCxxp8twBcZxWy',
# ...

# %%
audio_feat_for_df20 = df_for_20[df_for_20['track_id'].isin(for_list19)]
audio_feat_for_df20 = audio_feat_for_df20[audio_feat].drop_duplicates()
audio_feat_for_df20
# Out:
#         duration  popularity  danceability  energy  key  loudness  mode  \
# 152149    189486          88         0.764   0.320   11    -7.209     1
# 152150    163636          86         0.621   0.601    6    -5.616     0
# 152151    358015          32         0.848   0.447    5   -10.560     0
# 152152    232853           4         0.746   0.450    7    -8.543     1
# 152153    167693          84         0.654   0.630   10    -4.644     1
# ...          ...         ...           ...     ...  ...       ...   ...
# 158388    215733          84         0.572   0.385    7    -6.362     1
# 166880    207520          81         0.522   0.385    0    -7.355     1
# 174378    213264          68         0.786   0.853    8    -2.687     1
# 174438    209355          76         0.671   0.859    4    -3.922     0
# 174484    169566          72         0.751   0.642    3    -5.165     0
#
#         speechiness  acousticness  instrumentalness  liveness  valence  \
# ...

# %%
audio_feat_for_df20['duration'] = audio_feat_for_df20['duration'] / 60000
audio_feat_for_df20
# Out:
#         duration  popularity  danceability  energy  key  loudness  mode  \
# 152149  3.158100          88         0.764   0.320   11    -7.209     1
# 152150  2.727267          86         0.621   0.601    6    -5.616     0
# 152151  5.966917          32         0.848   0.447    5   -10.560     0
# 152152  3.880883           4         0.746   0.450    7    -8.543     1
# 152153  2.794883          84         0.654   0.630   10    -4.644     1
# ...          ...         ...           ...     ...  ...       ...   ...
# 158388  3.595550          84         0.572   0.385    7    -6.362     1
# 166880  3.458667          81         0.522   0.385    0    -7.355     1
# 174378  3.554400          68         0.786   0.853    8    -2.687     1
# 174438  3.489250          76         0.671   0.859    4    -3.922     0
# 174484  2.826100          72         0.751   0.642    3    -5.165     0
#
#         speechiness  acousticness  instrumentalness  liveness  valence  \
# ...

# %%
audio_feat_for_df20.describe()
# Out:
#         duration  popularity  danceability     energy        key   loudness  \
# count  78.000000   78.000000     78.000000  78.000000  78.000000  78.000000
# mean    3.491561   71.846154      0.650692   0.567141   5.371795  -6.768103
# std     0.535154   16.442009      0.137771   0.168310   3.516599   2.441345
# min     2.617767    4.000000      0.288000   0.178000   0.000000 -16.541000
# 25%     3.152675   67.000000      0.576250   0.425500   2.000000  -8.103500
# 50%     3.447033   76.000000      0.682500   0.554000   5.000000  -6.703000
# 75%     3.675604   81.750000      0.747500   0.680500   8.000000  -4.958500
# max     5.966917   90.000000      0.901000   0.882000  11.000000  -2.150000
#
#             mode  speechiness  acousticness  instrumentalness   liveness  \
# count  78.000000    78.000000     78.000000         78.000000  78.000000
# mean    0.743590     0.088477      0.316407          0.001796   0.150783
# ...

# %% [markdown]
# # Bar Charts

# %%
# data frames: audio_feat_for_df17, audio_feat_for_df18, audio_feat_for_df19, audio_feat_for_df20
audio_feat = ['duration','popularity', 'danceability', 'energy', 'key', 'loudness', 'mode','speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo']
yr_ = [2017, 2018, 2019, 2020]

# %%
sns.barplot(x = yr_, y = [audio_feat_for_df17['duration'].mean(),audio_feat_for_df18['duration'].mean(),audio_feat_for_df19['duration'].mean(),audio_feat_for_df20['duration'].mean()])
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x = yr_, y = [audio_feat_for_df17['duration'].mean(),audio_feat_for_df18['duration'].mean(),audio_feat_for_df19['duration'].mean(),audio_feat_for_df20['duration'].mean()])
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x = yr_, y = [audio_feat_for_df17['popularity'].mean(),audio_feat_for_df18['popularity'].mean(),audio_feat_for_df19['popularity'].mean(),audio_feat_for_df20['popularity'].mean()])
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x = yr_, y = [audio_feat_for_df17['danceability'].mean(),audio_feat_for_df18['danceability'].mean(),audio_feat_for_df19['danceability'].mean(),audio_feat_for_df20['danceability'].mean()])
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x = yr_, y = [audio_feat_for_df17['energy'].mean(),audio_feat_for_df18['energy'].mean(),audio_feat_for_df19['energy'].mean(),audio_feat_for_df20['energy'].mean()])
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x = yr_, y = [audio_feat_for_df17['key'].mean(),audio_feat_for_df18['key'].mean(),audio_feat_for_df19['key'].mean(),audio_feat_for_df20['key'].mean()])
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x = yr_, y = [audio_feat_for_df17['loudness'].mean(),audio_feat_for_df18['loudness'].mean(),audio_feat_for_df19['loudness'].mean(),audio_feat_for_df20['loudness'].mean()])
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x = yr_, y = [audio_feat_for_df17['mode'].mean(),audio_feat_for_df18['mode'].mean(),audio_feat_for_df19['mode'].mean(),audio_feat_for_df20['mode'].mean()])
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x = yr_, y = [audio_feat_for_df17['speechiness'].mean(),audio_feat_for_df18['speechiness'].mean(),audio_feat_for_df19['speechiness'].mean(),audio_feat_for_df20['speechiness'].mean()])
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x = yr_, y = [audio_feat_for_df17['acousticness'].mean(),audio_feat_for_df18['acousticness'].mean(),audio_feat_for_df19['acousticness'].mean(),audio_feat_for_df20['acousticness'].mean()])
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x = yr_, y = [audio_feat_for_df17['instrumentalness'].mean(),audio_feat_for_df18['instrumentalness'].mean(),audio_feat_for_df19['instrumentalness'].mean(),audio_feat_for_df20['instrumentalness'].mean()])
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x = yr_, y = [audio_feat_for_df17['liveness'].mean(),audio_feat_for_df18['liveness'].mean(),audio_feat_for_df19['liveness'].mean(),audio_feat_for_df20['liveness'].mean()])
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x = yr_, y = [audio_feat_for_df17['valence'].mean(),audio_feat_for_df18['valence'].mean(),audio_feat_for_df19['valence'].mean(),audio_feat_for_df20['valence'].mean()])
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x = yr_, y = [audio_feat_for_df17['tempo'].mean(),audio_feat_for_df18['tempo'].mean(),audio_feat_for_df19['tempo'].mean(),audio_feat_for_df20['tempo'].mean()])
# Out:
# <AxesSubplot:>
